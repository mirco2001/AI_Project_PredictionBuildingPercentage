# %%
#si importano tutte le librerie necessarie
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.python.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import pathlib
# Out:
# WARNING:tensorflow:From c:\Users\Utente PC\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Preparing The Data

# %%
#ottenimento della cartella con il nostro dataset
data_dir = pathlib.Path('C:/Users/Utente PC/Desktop/ProgettoIA/ai_course_template/data/class5')
print(data_dir)
# Out:
# C:\Users\Utente PC\Desktop\ProgettoIA\ai_course_template\data\class5

# %%
#test del contenuto all'interno di una cartella
images_dt = list(data_dir.glob('76-80%/*'))
print(str(images_dt[0]))
PIL.Image.open(str(images_dt[0]))
# Out:
# C:\Users\Utente PC\Desktop\ProgettoIA\ai_course_template\data\class5\76-80%\0.1.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x1080>

# %%
#set delle immagini che verranno utilizzate come training
img_height,img_width=180,180
batch_size=32  #numero di campioni di dati utilizzati in un epoca (ogni epoca addestra su tutto il dataset che viene suddiviso in vari batch)
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2, # 20% dataset per il test
  subset="training",
  seed=123, #garantire che la suddivisione dei dati sia riproducibile
  label_mode='categorical', #le etichette vengono rappresentate in one-hot encoding (casistica di classificazione con più classi)
  image_size=(img_height, img_width),
  batch_size=batch_size)

'''In train_ds abbiamo oggetti di tipo tipo tf.data.Dataset e contengono coppie di immagini e 
relative etichette sotto forma di tensori. Le immagini in questi dataset sono rappresentate come tensori di pixel, 
dove ogni pixel può avere un valore numerico che rappresenta l'intensità del colore. Ad esempio, se l'immagine è a colori, i tensori 
saranno tensori tridimensionali, con dimensioni che rappresentano altezza, larghezza e canali di colore (solitamente 3 per RGB). 
Se l'immagine è in scala di grigi, avrà solo due dimensioni.'''
# Out:
# Found 1300 files belonging to 20 classes.
# Using 1040 files for training.
# "In train_ds abbiamo oggetti di tipo tipo tf.data.Dataset e contengono coppie di immagini e \nrelative etichette sotto forma di tensori. Le immagini in questi dataset sono rappresentate come tensori di pixel, \ndove ogni pixel può avere un valore numerico che rappresenta l'intensità del colore. Ad esempio, se l'immagine è a colori, i tensori \nsaranno tensori tridimensionali, con dimensioni che rappresentano altezza, larghezza e canali di colore (solitamente 3 per RGB). \nSe l'immagine è in scala di grigi, avrà solo due dimensioni."

# %%
#set delle immagini che verranno utilizzate come testing
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  label_mode='categorical',
  image_size=(img_height, img_width),
  batch_size=batch_size)

val_ds_list = list(val_ds.as_numpy_iterator())
# Out:
# Found 1300 files belonging to 20 classes.
# Using 260 files for validation.

# %%
#stampa delle classi trovate all'interno del dataset
class_names = train_ds.class_names
print(class_names)
# Out:
# ['0-5%', '11-15%', '16-20%', '21-25%', '26-30%', '31-35%', '36-40%', '41-45%', '46-50%', '51-55%', '56-60%', '6-10%', '61-65%', '66-70%', '71-75%', '76-80%', '81-85%', '86-90%', '91-95%', '96-100%']

# %%
#esempi di immagini all'interno delle corrispettive classi
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
      ax = plt.subplot(3, 3, i + 1)
      plt.imshow(images[i].numpy().astype("uint8"))

      lablePos = 0
      for oneHotpos in range(len(labels[i].numpy())):
        if labels[i].numpy()[oneHotpos] == 1.0:
          lablePos = oneHotpos
          break

      plt.title(class_names[lablePos])
      plt.axis("off")

# %% [markdown]
# # Training The Model

# %%
VGG19_model = Sequential() #creazione modello sequenziale

pretrained_model= tf.keras.applications.VGG19(include_top=False, #non includere top layer che si occupano di classificazione e previsione
                   input_shape=(180,180,3),
                   pooling='avg',classes=20, #riduciamo dimensione spaziale feature map calcolando la media dei valori per ogni regione (riduciamo numero parametri e numero computazioni)
                   weights='imagenet') # permette di individuare di utilizzare dei modelli pre addestrati che sono già in grado di riconoscere degli oggetti o immagini

for layer in pretrained_model.layers: #cicla su tutti i pesi del modello pre impostati da ImageNet
        layer.trainable=False #i pesi non verranno aggiornati in fase di training

VGG19_model.add(pretrained_model) #il modello pre-addestrato diventa il primo layer del modello che stiamo definendo
VGG19_model.add(Flatten())  #aggiungo strato che trasforma l'output tridimensionale in vettore monodimensionale
VGG19_model.add(Dense(512, activation='relu')) #aggiungo layer connesso con 512 neuroni e funzione di attivazione relu (se output x del layer precedente è >0 restituisce x, se x è negativo restituisce 0)
VGG19_model.add(Dense(20, activation='softmax')) #aggiungo layer connesso con 20 neuroni (uno per classe) e funzione softmax che converte output in probabilità (definisce distribuzione probabilità tra le varie classi)
# Out:
# WARNING:tensorflow:From c:\Users\Utente PC\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Utente PC\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
VGG19_model.summary() #rappresentazione testuale del modello
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 512)               20024384
#
#  module_wrapper (ModuleWrap  (None, 512)               0
#  per)
#
#  module_wrapper_1 (ModuleWr  (None, 512)               262656
#  apper)
#
#  module_wrapper_2 (ModuleWr  (None, 20)                10260
#  apper)
#
# =================================================================
# Total params: 20297300 (77.43 MB)
# Trainable params: 272916 (1.04 MB)
# Non-trainable params: 20024384 (76.39 MB)
# _________________________________________________________________

# %%
VGG19_model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
 #configurazione: adam è l'ottimizzatore da usare
 #definisco funzione di perdità da minimizzare (categorical crossentropy è particolarmente adatta quando si lavora con output softmax, poiché
#misura la discrepanza tra le distribuzioni delle probabilità predette e reali), la metrica da monitorare durante l'addestramento è l'accurate
# Out:
# WARNING:tensorflow:From c:\Users\Utente PC\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
from keras import callbacks
earlystopping = callbacks.EarlyStopping(monitor='val_loss',mode='min',patience=5,restore_best_weights=True, verbose=1)

# %%
epochs=30  #numero di singole iterazioni nell'addestramento, ogni epoca valuta tutto il dataset
history = VGG19_model.fit(  #fit è il metodo di addestramento
  train_ds,  #passo il dataset per il training
  validation_data=val_ds,  #passo il dataset per il testing
  epochs=epochs, #passo numero epoche
  callbacks=[earlystopping] #callback per stoppare esecuzione
)
# Out:
# Epoch 1/30
# WARNING:tensorflow:From c:\Users\Utente PC\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Utente PC\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 33/33 [==============================] - 157s 5s/step - loss: 5.4207 - accuracy: 0.1038 - val_loss: 3.4119 - val_accuracy: 0.1231
# Epoch 2/30
# 33/33 [==============================] - 136s 4s/step - loss: 1.9428 - accuracy: 0.4067 - val_loss: 2.6383 - val_accuracy: 0.2346
# Epoch 3/30
# 33/33 [==============================] - 133s 4s/step - loss: 1.1509 - accuracy: 0.6317 - val_loss: 2.2902 - val_accuracy: 0.2962
# Epoch 4/30
# 33/33 [==============================] - 151s 5s/step - loss: 0.6803 - accuracy: 0.8087 - val_loss: 2.1404 - val_accuracy: 0.3885
# Epoch 5/30
# 33/33 [==============================] - 136s 4s/step - loss: 0.4514 - accuracy: 0.8923 - val_loss: 2.0929 - val_accuracy: 0.3962
# Epoch 6/30
# 33/33 [==============================] - 138s 4s/step - loss: 0.3189 - accuracy: 0.9288 - val_loss: 1.9767 - val_accuracy: 0.4615
# Epoch 7/30
# 33/33 [==============================] - 136s 4s/step - loss: 0.2118 - accuracy: 0.9615 - val_loss: 2.0029 - val_accuracy: 0.4500
# Epoch 8/30
# 33/33 [==============================] - 134s 4s/step - loss: 0.1540 - accuracy: 0.9760 - val_loss: 1.9279 - val_accuracy: 0.4577
# Epoch 9/30
# 33/33 [==============================] - 146s 4s/step - loss: 0.1231 - accuracy: 0.9808 - val_loss: 1.9831 - val_accuracy: 0.4308
# Epoch 10/30
# 33/33 [==============================] - 116s 3s/step - loss: 0.1041 - accuracy: 0.9817 - val_loss: 1.9715 - val_accuracy: 0.4269
# Epoch 11/30
# 33/33 [==============================] - 109s 3s/step - loss: 0.0866 - accuracy: 0.9885 - val_loss: 1.9512 - val_accuracy: 0.4346
# Epoch 12/30
# 33/33 [==============================] - 99s 3s/step - loss: 0.0705 - accuracy: 0.9875 - val_loss: 1.9409 - val_accuracy: 0.4462
# Epoch 13/30
# 33/33 [==============================] - 100s 3s/step - loss: 0.0651 - accuracy: 0.9875 - val_loss: 1.9084 - val_accuracy: 0.4462
# Epoch 14/30
# 33/33 [==============================] - 103s 3s/step - loss: 0.0570 - accuracy: 0.9904 - val_loss: 1.9254 - val_accuracy: 0.4577
# Epoch 15/30
# 33/33 [==============================] - 99s 3s/step - loss: 0.0627 - accuracy: 0.9894 - val_loss: 2.0081 - val_accuracy: 0.4346
# Epoch 16/30
# 33/33 [==============================] - 100s 3s/step - loss: 0.0768 - accuracy: 0.9904 - val_loss: 1.9070 - val_accuracy: 0.4346
# Epoch 17/30
# 33/33 [==============================] - 101s 3s/step - loss: 0.0495 - accuracy: 0.9904 - val_loss: 1.9531 - val_accuracy: 0.4500
# Epoch 18/30
# 33/33 [==============================] - 100s 3s/step - loss: 0.0511 - accuracy: 0.9913 - val_loss: 2.1441 - val_accuracy: 0.3962
# Epoch 19/30
# 33/33 [==============================] - 99s 3s/step - loss: 0.0561 - accuracy: 0.9885 - val_loss: 1.9965 - val_accuracy: 0.4500
# Epoch 20/30
# 33/33 [==============================] - 99s 3s/step - loss: 0.0691 - accuracy: 0.9856 - val_loss: 2.0085 - val_accuracy: 0.4462
# Epoch 21/30
# 33/33 [==============================] - ETA: 0s - loss: 0.0471 - accuracy: 0.9913Restoring model weights from the end of the best epoch: 16.
# 33/33 [==============================] - 96s 3s/step - loss: 0.0471 - accuracy: 0.9913 - val_loss: 1.9442 - val_accuracy: 0.4615
# Epoch 21: early stopping

# %% [markdown]
# # Evaluating The Model

# %%
fig1 = plt.gcf()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.axis(ymin=0.0,ymax=1)
plt.grid()
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.grid()
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
y_true = []          
for _,labels in val_ds_list:
    lablePos = 0
    for i in range(len(labels)):
        for oneHotpos in range(len(labels[i])):
            if labels[i][oneHotpos] == 1.0:
                lablePos = oneHotpos
                y_true.append(class_names[lablePos])
                break

print(y_true)

predictions = []
for batch_images, _ in val_ds_list:
    batch_predictions = VGG19_model.predict(batch_images)
    predictions.append(batch_predictions)

predictions = np.concatenate(predictions, axis=0)
#print(predictions)

y_test = []
for i in range(len(predictions)):
    y_test.append(class_names[np.argmax(predictions[i])])

print(y_test)
# Out:
# ['36-40%', '66-70%', '36-40%', '81-85%', '66-70%', '41-45%', '86-90%', '51-55%', '26-30%', '41-45%', '46-50%', '71-75%', '0-5%', '41-45%', '16-20%', '21-25%', '46-50%', '6-10%', '46-50%', '36-40%', '86-90%', '86-90%', '96-100%', '41-45%', '61-65%', '31-35%', '41-45%', '51-55%', '81-85%', '91-95%', '0-5%', '56-60%', '86-90%', '76-80%', '86-90%', '51-55%', '76-80%', '51-55%', '76-80%', '21-25%', '96-100%', '81-85%', '51-55%', '86-90%', '21-25%', '96-100%', '66-70%', '36-40%', '36-40%', '41-45%', '66-70%', '6-10%', '16-20%', '96-100%', '61-65%', '16-20%', '91-95%', '46-50%', '81-85%', '46-50%', '21-25%', '51-55%', '6-10%', '46-50%', '36-40%', '81-85%', '21-25%', '96-100%', '61-65%', '56-60%', '36-40%', '76-80%', '16-20%', '11-15%', '86-90%', '36-40%', '16-20%', '16-20%', '46-50%', '36-40%', '41-45%', '26-30%', '31-35%', '26-30%', '81-85%', '61-65%', '81-85%', '41-45%', '56-60%', '26-30%', '61-65%', '41-45%', '0-5%', '46-50%', '86-90%', '51-55%', '61-65%', '0-5%', '76-80%', '26-30%', '66-70%', '56-60%', '76-80%', '41-45%', '21-25%', '0-5%', '51-55%', '51-55%', '16-20%', '96-100%', '96-100%', '86-90%', '36-40%', '31-35%', '66-70%', '86-90%', '6-10%', '21-25%', '0-5%', '36-40%', '6-10%', '31-35%', '0-5%', '36-40%', '51-55%', '6-10%', '76-80%', '81-85%', '86-90%', '81-85%', '81-85%', '76-80%', '76-80%', '51-55%', '41-45%', '71-75%', '31-35%', '41-45%', '56-60%', '61-65%', '61-65%', '56-60%', '76-80%', '51-55%', '41-45%', '21-25%', '51-55%', '6-10%', '76-80%', '36-40%', '71-75%', '66-70%', '36-40%', '26-30%', '86-90%', '16-20%', '16-20%', '51-55%', '41-45%', '0-5%', '86-90%', '16-20%', '71-75%', '91-95%', '86-90%', '61-65%', '71-75%', '96-100%', '66-70%', '86-90%', '11-15%', '96-100%', '46-50%', '96-100%', '61-65%', '76-80%', '36-40%', '26-30%', '6-10%', '91-95%', '0-5%', '86-90%', '11-15%', '36-40%', '71-75%', '71-75%', '16-20%', '51-55%', '51-55%', '11-15%', '96-100%', '6-10%', '46-50%', '46-50%', '76-80%', '41-45%', '11-15%', '51-55%', '36-40%', '0-5%', '41-45%', '61-65%', '0-5%', '16-20%', '31-35%', '11-15%', '6-10%', '61-65%', '11-15%', '46-50%', '26-30%', '31-35%', '31-35%', '21-25%', '81-85%', '46-50%', '96-100%', '11-15%', '76-80%', '0-5%', '81-85%', '31-35%', '66-70%', '66-70%', '41-45%', '66-70%', '0-5%', '31-35%', '11-15%', '71-75%', '26-30%', '41-45%', '51-55%', '26-30%', '66-70%', '86-90%', '0-5%', '76-80%', '46-50%', '26-30%', '0-5%', '31-35%', '91-95%', '41-45%', '61-65%', '31-35%', '51-55%', '66-70%', '91-95%', '6-10%', '81-85%', '16-20%', '91-95%', '71-75%', '6-10%', '41-45%', '31-35%', '6-10%', '41-45%', '31-35%']
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 426ms/step
# ['36-40%', '66-70%', '41-45%', '61-65%', '96-100%', '41-45%', '86-90%', '51-55%', '31-35%', '41-45%', '46-50%', '86-90%', '0-5%', '56-60%', '16-20%', '26-30%', '0-5%', '0-5%', '46-50%', '36-40%', '91-95%', '66-70%', '91-95%', '36-40%', '66-70%', '31-35%', '46-50%', '41-45%', '81-85%', '96-100%', '0-5%', '81-85%', '86-90%', '71-75%', '86-90%', '56-60%', '46-50%', '91-95%', '81-85%', '21-25%', '96-100%', '81-85%', '51-55%', '81-85%', '21-25%', '96-100%', '56-60%', '36-40%', '36-40%', '46-50%', '66-70%', '11-15%', '21-25%', '96-100%', '51-55%', '6-10%', '91-95%', '56-60%', '81-85%', '46-50%', '21-25%', '51-55%', '6-10%', '46-50%', '36-40%', '71-75%', '26-30%', '91-95%', '61-65%', '41-45%', '41-45%', '71-75%', '21-25%', '11-15%', '86-90%', '31-35%', '21-25%', '11-15%', '51-55%', '36-40%', '36-40%', '31-35%', '31-35%', '26-30%', '81-85%', '51-55%', '96-100%', '56-60%', '36-40%', '21-25%', '26-30%', '36-40%', '0-5%', '41-45%', '91-95%', '51-55%', '61-65%', '6-10%', '81-85%', '21-25%', '61-65%', '56-60%', '76-80%', '26-30%', '11-15%', '0-5%', '51-55%', '51-55%', '16-20%', '96-100%', '96-100%', '81-85%', '36-40%', '36-40%', '66-70%', '81-85%', '21-25%', '0-5%', '21-25%', '36-40%', '6-10%', '31-35%', '6-10%', '36-40%', '56-60%', '6-10%', '56-60%', '81-85%', '86-90%', '81-85%', '91-95%', '81-85%', '66-70%', '46-50%', '36-40%', '91-95%', '31-35%', '46-50%', '61-65%', '56-60%', '66-70%', '51-55%', '71-75%', '46-50%', '41-45%', '21-25%', '36-40%', '11-15%', '66-70%', '36-40%', '86-90%', '71-75%', '41-45%', '31-35%', '86-90%', '21-25%', '21-25%', '51-55%', '36-40%', '0-5%', '81-85%', '11-15%', '71-75%', '91-95%', '86-90%', '66-70%', '76-80%', '96-100%', '96-100%', '91-95%', '21-25%', '76-80%', '51-55%', '96-100%', '6-10%', '81-85%', '41-45%', '31-35%', '6-10%', '91-95%', '6-10%', '81-85%', '16-20%', '36-40%', '96-100%', '76-80%', '16-20%', '56-60%', '51-55%', '11-15%', '76-80%', '0-5%', '51-55%', '41-45%', '91-95%', '91-95%', '26-30%', '96-100%', '36-40%', '0-5%', '41-45%', '56-60%', '0-5%', '21-25%', '31-35%', '11-15%', '6-10%', '61-65%', '26-30%', '46-50%', '16-20%', '31-35%', '21-25%', '21-25%', '96-100%', '46-50%', '81-85%', '21-25%', '71-75%', '31-35%', '81-85%', '31-35%', '61-65%', '61-65%', '36-40%', '66-70%', '6-10%', '31-35%', '11-15%', '76-80%', '21-25%', '46-50%', '51-55%', '91-95%', '66-70%', '86-90%', '0-5%', '86-90%', '46-50%', '21-25%', '6-10%', '31-35%', '96-100%', '6-10%', '71-75%', '31-35%', '51-55%', '66-70%', '81-85%', '6-10%', '76-80%', '0-5%', '91-95%', '71-75%', '6-10%', '41-45%', '31-35%', '11-15%', '66-70%', '31-35%']

# %%
class_cont = [0]*len(class_names)

for j in range(len(class_names)):
    class_perc = class_names[j]
    for x in range(len(y_true)):
        if(class_perc == y_true[x]):
            if(y_true[x] != y_test[x]):
                class_cont[j] = class_cont[j] + 1

print(class_cont)
# Out:
# [7, 5, 10, 4, 10, 2, 5, 16, 7, 9, 5, 6, 10, 7, 7, 14, 6, 9, 3, 5]

# %%
fig, ax = plt.subplots()

fig.set_figwidth(20)

bar_container = ax.bar(class_names, class_cont)

ax.set_ylabel('Number of errors')
ax.set_title('Model errors by class')
ax.bar_label(bar_container, fmt='{:,.0f}')

plt.show()

# %%
import json

from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input

import shap

# load pre-trained model and choose two images to explain
model = VGG19_model
class_names = ['0-%5','6-10%','11-15%','16-20%','21-25%','26-30%','31-35%','36-40%','41-45%','46-50%','51-55%','56-60%','61-65%','66-70%','71-75%','76-80%','81-85%','86-90%','91-95%','96-100%']

def f(test_nparray):
    tmp = test_nparray.copy()
    preprocess_input(tmp)
    return model(tmp)


#X, y = shap.datasets.imagenet50()
#print(type(X))

test = []
for images, _ in val_ds_list[0:32]:
    for i in range(len(images)):
        test.append(images[i])

test_nparray = np.array(test)
#print(test_nparray)
#print(class_names)

# define a masker that is used to mask out partitions of the input image, this one uses a blurred background
masker = shap.maskers.Image("inpaint_telea", test_nparray[0].shape)

# By default the Partition explainer is used for all  partition explainer
explainer = shap.Explainer(f, masker, output_names=class_names)

# here we use 500 evaluations of the underlying model to estimate the SHAP values
#print(test_nparray[1:3])
#print(X[1:3])

shap_values = explainer(
    test_nparray[1:5].astype("uint8"), max_evals=500, batch_size=32, outputs=shap.Explanation.argsort.flip[:3]
)
shap.image_plot(shap_values)
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
# PartitionExplainer explainer: 5it [02:58, 44.72s/it]

# %%
VGG19_model.save('VGG19(class5)')
# Out:
# INFO:tensorflow:Assets written to: VGG19(class5)\assets
# INFO:tensorflow:Assets written to: VGG19(class5)\assets
